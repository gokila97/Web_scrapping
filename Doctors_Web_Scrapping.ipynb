# %% [markdown]
# <a href="https://colab.research.google.com/github/gokila97/Web_scrapping/blob/main/Doctors_Web_Scrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. **Installaling  the required third-part libraries**

# %%
pip install requests

# %%
pip install get

# %%
pip install B4
# Out:
# ...
#      |████████████████████████████████| 67 kB 2.7 MB/s
# ...
#      |████████████████████████████████| 59 kB 5.7 MB/s
# ...
#      |████████████████████████████████| 241 kB 14.1 MB/s
# ...
#      |████████████████████████████████| 62 kB 799 kB/s
# ...
#      |████████████████████████████████| 961 kB 45.0 MB/s
# ...
#   Created wheel for dkimpy: filename=dkimpy-1.0.5-py3-none-any.whl size=48749 sha256=32ef297bd2f781c36ec7c6e0929fa99a98ea899dca1c4914d7e20a5940d018a9
#   Stored in directory: /root/.cache/pip/wheels/a6/b3/b2/6250742938e606f2913bc5fd00c083ca43c5abecba9a534560
# Successfully built dkimpy
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
pip install html5lib

# %%
pip install urllib3

# %%
pip install bs4

# %% [markdown]
# 2.**Importing Library**

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
import pandas as pd
df = pd.read_csv("/Doctors_details_csv - Sheet1 (4).csv")
print(df)
# Out:
#                Doctor_Name  ...                                Contact_detail_link
# 0         Dr.Agrawal Nisha  ...               https://www.drdata.in/drnishaagrawal
# 1      Dr.Agrawal Himanshu  ...            https://www.drdata.in/drhimanshuagrawal
# 2    Dr.Agrawal Arun Kumar  ...                https://www.drdata.in/drarunagrawal
# 3         Dr.Achwal Suvama  ...                 https://www.drdata.in/drachwalbina
# 4       Dr.Priyank Agarwal  ...             https://www.drdata.in/drpriyankagarwal
# ..                     ...  ...                                                ...
# 495    Dr.Zothanpunia John  ...            https://www.drdata.in/drjohnzothanpunia
# 496         Dr.Shah Nita.M  ...                  https://www.drdata.in/drnitamshah
# 497       Dr.Shah Pankaj.O  ...                https://www.drdata.in/drpankajoshah
# 498      Dr.Swetal Shah .P  ...                 https://www.drdata.in/drswetapshah
# ...

# %% [markdown]
# 3.**Getting out the contac details for doctors**

# %%
import pandas as pd

# %%
dict = {
    "Doctors_Name": Doctors_Name_2,
    "Contact_detail_link": detail_link
}
df1 = "pd.DataFrame"(dict)

df1
df1.to_csv("/Doctors_details_csv - Sheet1 (4).csv",index=None)

df1

# %%
Doctors_Name_1=[]
for 1 in Doctors_Name_tag[0:15]:
  Doctors_Name_1.append(1.text.strip())

# %%
for 1 in phone_1.find_all("tbody")
rows = 1.find_all("td")
print(rows)

# %%
for row in rows
number = row.find("td")
print(number)

# %% [markdown]
# 4.**Scrape from websites**

# %%
URL = " https://www.drdata.in/drachwalbina"

# %%
r = requests.get(URL)

# %%
Doctors_Name_1=[]

# %%
URL = " https://www.drdata.in/drachwalbina"

# %%
r = requests.get(URL)

# %%
print(r.content)
# Out:
# b'\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n<!DOCTYPE html>\r\n<html lang="en">\r\n<head>\r\n\r\n<script async src="https://www.googletagmanager.com/gtag/js?id=UA-61981285-1"></script><script>var _$_48c7=["dataLayer","push","js","config","UA-61981285-1"];window[_$_48c7[0]]= window[_$_48c7[0]]|| [];function gtag(){dataLayer[_$_48c7[1]](arguments)}gtag(_$_48c7[2], new Date());gtag(_$_48c7[3],_$_48c7[4])</script><script>(function(i,s,o,g,r,a,m){i[\'GoogleAnalyticsObject\']=r;i[r]=i[r]||function(){\n(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),\nm=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)\n})(window,document,\'script\',\'https://www.google-analytics.com/analytics.js\',\'ga\');\nga(\'create\', \'UA-61981285-1\', \'auto\');\nga(\'send\', \'pageview\');</script><meta charset="utf-8"><meta http-equiv="X-UA-Compatible" content="IE=e
# ...

# %%
import requests

# %%
res = requests.get("https://www.drdata.in/drachwalbina")

# %%
print(res.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#
# <script async src="https://www.googletagmanager.com/gtag/js?id=UA-61981285-1"></script><script>var _$_48c7=["dataLayer","push","js","config","UA-61981285-1"];window[_$_48c7[0]]= window[_$_48c7[0]]|| [];function gtag(){dataLayer[_$_48c7[1]](arguments)}gtag(_$_48c7[2], new Date());gtag(_$_48c7[3],_$_48c7[4])</script><script>(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
# ga('create', 'UA-61981285-1', 'auto');
# ...

# %% [markdown]
# Scrapping detail1

# %%
url = "https://www.drdata.in/drhimanshuagrawal"

# %%
request = "url.text"

# %%
print(res.status_code)
# Out:
# 200

# %%
"request"
# Out:
# 'request'

# %%
doc_url  #"https://www.drdata.in/drhimanshuagrawal"
# Out:
# 'https://www.drdata.in/drhimanshuagrawal'

# %%
r=requests.get(doc_url)

# %%
"07672-251077" in r.text
# Out:
# True

# %%
r.status_code
# Out:
# 200

# %%
len(r.text)
# Out:
# 96862

# %%
page = requests.get(" https://www.drdata.in/drhimanshuagrawal")

# %%
url = " https://www.drdata.in/drhimanshuagrawal"

# %%
print(dir(requests))
# Out:
# ['ConnectTimeout', 'ConnectionError', 'DependencyWarning', 'FileModeWarning', 'HTTPError', 'NullHandler', 'PreparedRequest', 'ReadTimeout', 'Request', 'RequestException', 'RequestsDependencyWarning', 'Response', 'Session', 'Timeout', 'TooManyRedirects', 'URLRequired', '__author__', '__author_email__', '__build__', '__builtins__', '__cached__', '__cake__', '__copyright__', '__description__', '__doc__', '__file__', '__license__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__title__', '__url__', '__version__', '_check_cryptography', '_internal_utils', 'adapters', 'api', 'auth', 'certs', 'chardet', 'check_compatibility', 'codes', 'compat', 'cookies', 'delete', 'exceptions', 'get', 'head', 'hooks', 'logging', 'models', 'options', 'packages', 'patch', 'post', 'put', 'request', 'session', 'sessions', 'status_codes', 'structures', 'urllib3', 'utils', 'warnings']

# %%
response = requests.get(url=url)

# %%
print(response)
# Out:
# <Response [200]>

# %%
headers = { 
    "user-agent"
}

# %%
print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#
# <script async src="https://www.googletagmanager.com/gtag/js?id=UA-61981285-1"></script><script>var _$_48c7=["dataLayer","push","js","config","UA-61981285-1"];window[_$_48c7[0]]= window[_$_48c7[0]]|| [];function gtag(){dataLayer[_$_48c7[1]](arguments)}gtag(_$_48c7[2], new Date());gtag(_$_48c7[3],_$_48c7[4])</script><script>(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
# ga('create', 'UA-61981285-1', 'auto');
# ...

# %%
print(type(response.text))
# Out:
# <class 'str'>

# %%
params = {
    "month":"June"
}

# %%
response = requests.get(url=url, params=params)

# %%
print(response.url)
# Out:
# https://www.drdata.in/drhimanshuagrawal?month=June

# %% [markdown]
# scrapping details2

# %%
url = "https://www.drdata.in/drachwalbina"

# %%
payload = {
    "name": "Achawal Suvama"
}

# %%
response = requests.post(url=url, data=payload)

# %%
print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#
# <script async src="https://www.googletagmanager.com/gtag/js?id=UA-61981285-1"></script><script>var _$_48c7=["dataLayer","push","js","config","UA-61981285-1"];window[_$_48c7[0]]= window[_$_48c7[0]]|| [];function gtag(){dataLayer[_$_48c7[1]](arguments)}gtag(_$_48c7[2], new Date());gtag(_$_48c7[3],_$_48c7[4])</script><script>(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
# ga('create', 'UA-61981285-1', 'auto');
# ...

# %%
"07580-223076" in r.text
# Out:
# False

# %%
params = {
    "month": "May"
}

# %%
response = requests.get(url=url,params=params)

# %%
print(response.url)
# Out:
# https://www.drdata.in/drachwalbina?month=May
